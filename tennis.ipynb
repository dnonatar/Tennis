# %%
import pandas as pd
import numpy as np

atp_2017 = pd.read_csv('./tennis_atp-master/atp_matches_2017.csv',sep=',',header=0)
atp_2017 = atp_2017.iloc[:,:47]
atp_2017.head(5)
atp_2017.columns = [u'surface', u'draw_size',
       u'tourney_level', u'tourney_date', u'match_num', u'winner_id',
       u'winner_seed', u'winner_entry', u'winner_name', u'winner_hand',
       u'winner_ht', u'winner_ioc', u'winner_age', u'winner_rank',
       u'winner_rank_points', u'loser_id', u'loser_seed', u'loser_entry',
       u'loser_name', u'loser_hand', u'loser_ht', u'loser_ioc', u'loser_age',
       u'loser_rank', u'loser_rank_points', u'score', u'best_of', u'round',
       u'minutes', u'w_ace', u'w_df', u'w_svpt', u'w_1stIn', u'w_1stWon',
       u'w_2ndWon', u'w_SvGms', u'w_bpSaved', u'w_bpFaced', u'l_ace', u'l_df',
       u'l_svpt', u'l_1stIn', u'l_1stWon', u'l_2ndWon', u'l_SvGms',
       u'l_bpSaved', u'l_bpFaced']

atp_2017.head(5)
# Out:
#                    surface  draw_size tourney_level  tourney_date  match_num  \
# 2017-M020 Brisbane    Hard         32             A      20170102        300
#           Brisbane    Hard         32             A      20170102        299
#           Brisbane    Hard         32             A      20170102        298
#           Brisbane    Hard         32             A      20170102        297
#           Brisbane    Hard         32             A      20170102        296
#
#                     winner_id  winner_seed winner_entry      winner_name  \
# 2017-M020 Brisbane     105777          7.0          NaN  Grigor Dimitrov
#           Brisbane     105777          7.0          NaN  Grigor Dimitrov
#           Brisbane     105453          3.0          NaN    Kei Nishikori
#           Brisbane     105683          1.0          NaN     Milos Raonic
#           Brisbane     105777          7.0          NaN  Grigor Dimitrov
#
#                    winner_hand    ...     w_bpFaced l_ace  l_df  l_svpt  \
# 2017-M020 Brisbane           R    ...           7.0   4.0   0.0    69.0
#           Brisbane           R    ...           0.0   4.0   3.0    61.0
#           Brisbane           R    ...           5.0   9.0   2.0    61.0
#           Brisbane           R    ...           7.0   4.0   0.0    84.0
#           Brisbane           R    ...          14.0   6.0   5.0    82.0
#
#                     l_1stIn  l_1stWon  l_2ndWon l_SvGms l_bpSaved l_bpFaced
# 2017-M020 Brisbane     49.0      36.0       9.0    12.0       2.0       5.0
#           Brisbane     28.0      24.0      16.0    10.0       2.0       4.0
#           Brisbane     37.0      27.0      10.0    10.0       0.0       2.0
#           Brisbane     61.0      39.0      14.0    14.0       2.0       4.0
#           Brisbane     37.0      29.0      24.0    14.0       4.0       7.0
#
# [5 rows x 47 columns]

# %%
atp_2017 = atp_2017[[u'surface',u'winner_name', u'winner_age', u'winner_rank',
       u'winner_rank_points', u'loser_seed', 
       u'loser_name', u'loser_age',
       u'loser_rank', u'loser_rank_points', u'score', u'best_of', u'round',
       u'minutes', u'w_ace', u'w_df', u'w_svpt', u'w_1stIn', u'w_1stWon',
       u'w_2ndWon', u'w_SvGms', u'w_bpSaved', u'w_bpFaced', u'l_ace', u'l_df',
       u'l_svpt', u'l_1stIn', u'l_1stWon', u'l_2ndWon', u'l_SvGms',
       u'l_bpSaved', u'l_bpFaced']]

# %%
nadal_2017 = atp_2017[(atp_2017['winner_name']=='Rafael Nadal') | (atp_2017['loser_name']=='Rafael Nadal')]
nadal_2017.head(7)
# Out:
#                           surface   winner_name  winner_age  winner_rank  \
# 2017-M020 Brisbane           Hard  Milos Raonic   26.017796          3.0
#           Brisbane           Hard  Rafael Nadal   30.584531          9.0
#           Brisbane           Hard  Rafael Nadal   30.584531          9.0
# 2017-580  Australian Open    Hard  Rafael Nadal   30.622861          9.0
#           Australian Open    Hard  Rafael Nadal   30.622861          9.0
#           Australian Open    Hard  Rafael Nadal   30.622861          9.0
#           Australian Open    Hard  Rafael Nadal   30.622861          9.0
#
#                            winner_rank_points  loser_seed  \
# 2017-M020 Brisbane                     5450.0         5.0
#           Brisbane                     3300.0         NaN
#           Brisbane                     3300.0         NaN
# 2017-580  Australian Open              3195.0         NaN
#           Australian Open              3195.0         NaN
#           Australian Open              3195.0        24.0
#           Australian Open              3195.0         6.0
#
#                                     loser_name  loser_age  loser_rank  \
# 2017-M020 Brisbane                Rafael Nadal  30.584531         9.0
#           Brisbane               Mischa Zverev  29.366188        51.0
#           Brisbane         Alexandr Dolgopolov  28.153320        62.0
# 2017-580  Australian Open        Florian Mayer  33.284052        49.0
#           Australian Open     Marcos Baghdatis  31.583847        36.0
#           Australian Open     Alexander Zverev  19.742642        24.0
#           Australian Open         Gael Monfils  30.376454         6.0
#
#                            loser_rank_points    ...     w_bpFaced  l_ace  \
# 2017-M020 Brisbane                    3300.0    ...           7.0    4.0
#           Brisbane                     874.0    ...           2.0    2.0
#           Brisbane                     760.0    ...           3.0    2.0
# 2017-580  Australian Open              903.0    ...           0.0    7.0
#           Australian Open             1210.0    ...           5.0    7.0
#           Australian Open             1655.0    ...           7.0   19.0
#           Australian Open             3625.0    ...           6.0   15.0
#
#                            l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 2017-M020 Brisbane          0.0    84.0     61.0      39.0      14.0     14.0
#           Brisbane          2.0    38.0     25.0      13.0       3.0      7.0
#           Brisbane          2.0    53.0     28.0      20.0       7.0      9.0
# 2017-580  Australian Open   1.0   102.0     66.0      41.0      22.0     14.0
#           Australian Open   4.0    98.0     53.0      33.0      16.0     12.0
#           Australian Open  11.0   172.0    108.0      77.0      27.0     24.0
#           Australian Open  10.0   130.0     76.0      50.0      24.0     19.0
#
#                            l_bpSaved  l_bpFaced
# 2017-M020 Brisbane               2.0        4.0
#           Brisbane               3.0        8.0
#           Brisbane               0.0        4.0
# 2017-580  Australian Open        9.0       12.0
#           Australian Open       10.0       16.0
#           Australian Open       11.0       16.0
#           Australian Open       11.0       17.0
#
# [7 rows x 32 columns]
